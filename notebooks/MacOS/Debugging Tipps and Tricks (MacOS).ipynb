# %% [markdown]
# # Debugging Tipps and Tricks (MacOS)
#
# In this notebook, we have collected some scripts that help debug the SDL if something goes wrong.
#
# Go to [sdl4kids.com](http://sdl4kids.com) for the Windows version.
#
# If you have any questions, check out the [FAQ](https://sites.google.com/matterhorn.studio/sdl4kids/faq)!

# %%
import random
import numpy as np
import cv2

# Function to generate random color
def generate_random_color():
    red = random.randint(0, 255)
    green = random.randint(0, 255)
    blue = random.randint(0, 255)
    return blue, green, red  # OpenCV uses BGR color format

# Function to calculate the error between two colors
def calculate_error(color1, color2):
    return np.sqrt((color1[0] - color2[0]) ** 2 + (color1[1] - color2[1]) ** 2 + (color1[2] - color2[2]) ** 2)

# %% [markdown]
# ## (1) Problem: Your computer screens colors are different to what the microbit measures
#
# The truth is, if you show the color red (255,0,0) on your screen, the microbit will measure something more like (180,50,50) as there will be background colors from your room intereferring.
#
# The code below will run 255 experiments, where we test all colors from (0,0,0) to (255,0,0), i.e. making the screen more and more red. In the plot below, showcasing the error and the different measurements, you can see that despite making the screen all red, we still measure some blue and green.

# %%
import serial
import pandas as pd

# %%
# !ls /dev/cu.*
# Out:
# /dev/cu.Bluetooth-Incoming-Port /dev/cu.ZeitlersBoseQC35II
# /dev/cu.RoastBeats              /dev/cu.usbmodem102

# %%
ser = serial.Serial()
ser = serial.Serial("/dev/cu.usbmodem102",115200, timeout=0.1)

# %%
import time
def characterise(wait=0.5):
    valid = False
    while not valid:
        try:
            ser.flushInput()
            ser.write(b",")
            serial_data = str(ser.readline().decode('utf8')).rstrip()
            rgb = tuple([int(value) for value in serial_data.split("-")])
            # Validate: Measurement needs three entries
            if len(rgb) != 3:
                print(f"Measurement did not containt 3 RGB values:{rgb}")
                raise Exception()
            # Validate: Measurements need to be between 0 and 255
            if sum([0 <= x <= 255 for x in rgb]) != 3:
                print(f"Measurement outside valid range [0,255]:{rgb}")
                raise Exception()
            valid = True
        except Exception as e:
            print(f"Measurement invalid, will try again (error: {str(e)})")
    print(f"New RGB Measurement: {rgb}")
    time.sleep(wait)
    return rgb

# %%
characterise()
# Out:
# New RGB Measurement: (90, 90, 76)
# (90, 90, 76)

# %%
import random
import numpy as np
import cv2

# Create a blank image
width, height = 800, 400
image = np.zeros((height, width, 3), dtype=np.uint8)

# Create a named window for display
cv2.namedWindow("Live Image", cv2.WINDOW_NORMAL)
cv2.startWindowThread()

# Define font properties for displaying text
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 0.8
font_color = (255, 255, 255)  # White color

# Define the goal color
goal_color = (255,0,0)  # Goal color

# Main loop
max_iterations = 255  # Set the desired number of iterations

# Let us set up a data table to record the data more structured
samples = pd.DataFrame(columns=['R', 'G', 'B', 'error', 'ID'])

candidate_color = (0,0,0) # Initial color

for iteration in range(max_iterations):
    print(f"---Iteration {iteration}")
    candidate_color = (iteration, 0, 0)

    # STEP 1: Synthesis
    # Update the live image with the current color
    print(f"Synthesis:{candidate_color}")
    image[:, :] = tuple(reversed(candidate_color))
    
    # Display the image
    cv2.imshow("Live Image", image)
    
    # STEP 2: Characterisation
    
    # Measure the color with the Microbit: We will do this eventually
    rgb_measurement = characterise(wait=0.002)  
    print(f"Characterisation:{rgb_measurement}")
    #rgb_measurement = (rgb_measurement[0]+np.random.normal(1),rgb_measurement[1]+np.random.normal(1),rgb_measurement[2]+np.random.normal(1))
    
    # STEP 3: Planning
    
    # Calculate the loss between the goal color and the current color
    error = calculate_error(goal_color, rgb_measurement)
    print(f"Error:{error}")

    # Add the sample to the data table
    new_sample = pd.DataFrame({"R":rgb_measurement[0], "G":rgb_measurement[1], "B":rgb_measurement[2], "ID":iteration, "error":error}, index=[iteration])
    samples = pd.concat([samples, new_sample], axis=0, ignore_index=True)

    #candidate = calculate_candidate(samples)
    #candidate_color = (candidate['R'], candidate['G'], candidate['B'])
    #print(f"Planning: Candidate:{candidate_color}")
    
    # Add text information to the image
    text = f"Iteration: {iteration + 1}"
    cv2.putText(image, text, (10, 30), font, font_scale, font_color, 2)

    # Plot a subplot for the goal color
    # subplot_x = num_iterations * (width // (max_iterations + 1))
    subplot_x = width // (max_iterations + 1)
    subplot_width = 50
    cv2.rectangle(image, (subplot_x, 60), (subplot_x + subplot_width, height - 60), tuple(reversed(goal_color)), -1)

    # Add text for the error
    error_text = f"Error: {error:.2f}"
    cv2.putText(image, error_text, (10, height - 10), font, font_scale, font_color, 2)

    error_values = list(samples['error'].to_numpy())    # Draw the graph of error values
    if len(error_values) > 1:
        for i in range(1, len(error_values)):
            x1 = (i - 1) * (width // max_iterations)
            y1 = height - int(error_values[i - 1] * (height - 60) / max(error_values))
            x2 = i * (width // max_iterations)
            y2 = height - int(error_values[i] * (height - 60) / max(error_values))
            cv2.line(image, (x1, y1), (x2, y2), (255, 255, 255), 2)

    # Increment the iteration counter
    cv2.imshow("Live Image", image)
    cv2.waitKey(1)  # Adjust the wait time (in milliseconds) as needed
    
# Close the window after the desired number of iterations
cv2.waitKey(1)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# ---Iteration 0
# Synthesis:(0, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 1
# Synthesis:(1, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 2
# Synthesis:(2, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 3
# Synthesis:(3, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 4
# Synthesis:(4, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 5
# Synthesis:(5, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 6
# Synthesis:(6, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 7
# Synthesis:(7, 0, 0)
# New RGB Measurement: (90, 90, 76)
# Characterisation:(90, 90, 76)
# Error:202.7338156302495
# ---Iteration 8
# Synthesis:(8, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 9
# Synthesis:(9, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 10
# Synthesis:(10, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 11
# Synthesis:(11, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 12
# Synthesis:(12, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 13
# Synthesis:(13, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 14
# Synthesis:(14, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 15
# Synthesis:(15, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 16
# Synthesis:(16, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 17
# Synthesis:(17, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 18
# Synthesis:(18, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 19
# Synthesis:(19, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 20
# Synthesis:(20, 0, 0)
# New RGB Measurement: (89, 91, 77)
# Characterisation:(89, 91, 77)
# Error:204.36731636932555
# ---Iteration 21
# Synthesis:(21, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 22
# Synthesis:(22, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 23
# Synthesis:(23, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 24
# Synthesis:(24, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 25
# Synthesis:(25, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 26
# Synthesis:(26, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 27
# Synthesis:(27, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 28
# Synthesis:(28, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 29
# Synthesis:(29, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 30
# Synthesis:(30, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 31
# Synthesis:(31, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 32
# Synthesis:(32, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 33
# Synthesis:(33, 0, 0)
# New RGB Measurement: (85, 114, 96)
# Characterisation:(85, 114, 96)
# Error:226.07963198837706
# ---Iteration 34
# Synthesis:(34, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 35
# Synthesis:(35, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 36
# Synthesis:(36, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 37
# Synthesis:(37, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 38
# Synthesis:(38, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 39
# Synthesis:(39, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 40
# Synthesis:(40, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 41
# Synthesis:(41, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 42
# Synthesis:(42, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 43
# Synthesis:(43, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 44
# Synthesis:(44, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 45
# Synthesis:(45, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 46
# Synthesis:(46, 0, 0)
# New RGB Measurement: (89, 112, 94)
# Characterisation:(89, 112, 94)
# Error:221.21482771279145
# ---Iteration 47
# Synthesis:(47, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 48
# Synthesis:(48, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 49
# Synthesis:(49, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 50
# Synthesis:(50, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 51
# Synthesis:(51, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 52
# Synthesis:(52, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 53
# Synthesis:(53, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 54
# Synthesis:(54, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 55
# Synthesis:(55, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 56
# Synthesis:(56, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 57
# Synthesis:(57, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 58
# Synthesis:(58, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 59
# Synthesis:(59, 0, 0)
# New RGB Measurement: (94, 106, 89)
# Characterisation:(94, 106, 89)
# Error:212.31580252067909
# ---Iteration 60
# Synthesis:(60, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 61
# Synthesis:(61, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 62
# Synthesis:(62, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 63
# Synthesis:(63, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 64
# Synthesis:(64, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 65
# Synthesis:(65, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 66
# Synthesis:(66, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 67
# Synthesis:(67, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 68
# Synthesis:(68, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 69
# Synthesis:(69, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 70
# Synthesis:(70, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 71
# Synthesis:(71, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 72
# Synthesis:(72, 0, 0)
# New RGB Measurement: (104, 102, 86)
# Characterisation:(104, 102, 86)
# Error:201.49689823915404
# ---Iteration 73
# Synthesis:(73, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 74
# Synthesis:(74, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 75
# Synthesis:(75, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 76
# Synthesis:(76, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 77
# Synthesis:(77, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 78
# Synthesis:(78, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 79
# Synthesis:(79, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 80
# Synthesis:(80, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 81
# Synthesis:(81, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 82
# Synthesis:(82, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 83
# Synthesis:(83, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 84
# Synthesis:(84, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 85
# Synthesis:(85, 0, 0)
# New RGB Measurement: (114, 93, 81)
# Characterisation:(114, 93, 81)
# Error:187.32591918898996
# ---Iteration 86
# Synthesis:(86, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 87
# Synthesis:(87, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 88
# Synthesis:(88, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 89
# Synthesis:(89, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 90
# Synthesis:(90, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 91
# Synthesis:(91, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 92
# Synthesis:(92, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 93
# Synthesis:(93, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 94
# Synthesis:(94, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 95
# Synthesis:(95, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 96
# Synthesis:(96, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 97
# Synthesis:(97, 0, 0)
# New RGB Measurement: (126, 86, 75)
# Characterisation:(126, 86, 75)
# Error:172.2265949265676
# ---Iteration 98
# Synthesis:(98, 0, 0)
# New RGB Measurement: (126, 86, 79)
# Characterisation:(126, 86, 79)
# Error:174.00574703152768
# ---Iteration 99
# Synthesis:(99, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 100
# Synthesis:(100, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 101
# Synthesis:(101, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 102
# Synthesis:(102, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 103
# Synthesis:(103, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 104
# Synthesis:(104, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 105
# Synthesis:(105, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 106
# Synthesis:(106, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 107
# Synthesis:(107, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 108
# Synthesis:(108, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 109
# Synthesis:(109, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 110
# Synthesis:(110, 0, 0)
# New RGB Measurement: (136, 79, 70)
# Characterisation:(136, 79, 70)
# Error:159.06602402776025
# ---Iteration 111
# Synthesis:(111, 0, 0)
# New RGB Measurement: (136, 82, 66)
# Characterisation:(136, 82, 66)
# Error:158.8741640418605
# ---Iteration 112
# Synthesis:(112, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 113
# Synthesis:(113, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 114
# Synthesis:(114, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 115
# Synthesis:(115, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 116
# Synthesis:(116, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 117
# Synthesis:(117, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 118
# Synthesis:(118, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 119
# Synthesis:(119, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 120
# Synthesis:(120, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 121
# Synthesis:(121, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 122
# Synthesis:(122, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 123
# Synthesis:(123, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 124
# Synthesis:(124, 0, 0)
# New RGB Measurement: (146, 73, 66)
# Characterisation:(146, 73, 66)
# Error:146.8536686637416
# ---Iteration 125
# Synthesis:(125, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 126
# Synthesis:(126, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 127
# Synthesis:(127, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 128
# Synthesis:(128, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 129
# Synthesis:(129, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 130
# Synthesis:(130, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 131
# Synthesis:(131, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 132
# Synthesis:(132, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 133
# Synthesis:(133, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 134
# Synthesis:(134, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 135
# Synthesis:(135, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 136
# Synthesis:(136, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 137
# Synthesis:(137, 0, 0)
# New RGB Measurement: (155, 67, 60)
# Characterisation:(155, 67, 60)
# Error:134.4953530795767
# ---Iteration 138
# Synthesis:(138, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 139
# Synthesis:(139, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 140
# Synthesis:(140, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 141
# Synthesis:(141, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 142
# Synthesis:(142, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 143
# Synthesis:(143, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 144
# Synthesis:(144, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 145
# Synthesis:(145, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 146
# Synthesis:(146, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 147
# Synthesis:(147, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 148
# Synthesis:(148, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 149
# Synthesis:(149, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 150
# Synthesis:(150, 0, 0)
# New RGB Measurement: (164, 61, 57)
# Characterisation:(164, 61, 57)
# Error:123.49493916756265
# ---Iteration 151
# Synthesis:(151, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 152
# Synthesis:(152, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 153
# Synthesis:(153, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 154
# Synthesis:(154, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 155
# Synthesis:(155, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 156
# Synthesis:(156, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 157
# Synthesis:(157, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 158
# Synthesis:(158, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 159
# Synthesis:(159, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 160
# Synthesis:(160, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 161
# Synthesis:(161, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 162
# Synthesis:(162, 0, 0)
# New RGB Measurement: (165, 59, 54)
# Characterisation:(165, 59, 54)
# Error:120.40348832155985
# ---Iteration 163
# Synthesis:(163, 0, 0)
# New RGB Measurement: (165, 59, 52)
# Characterisation:(165, 59, 52)
# Error:119.5198728245642
# ---Iteration 164
# Synthesis:(164, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 165
# Synthesis:(165, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 166
# Synthesis:(166, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 167
# Synthesis:(167, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 168
# Synthesis:(168, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 169
# Synthesis:(169, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 170
# Synthesis:(170, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 171
# Synthesis:(171, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 172
# Synthesis:(172, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 173
# Synthesis:(173, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 174
# Synthesis:(174, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 175
# Synthesis:(175, 0, 0)
# New RGB Measurement: (166, 58, 52)
# Characterisation:(166, 58, 52)
# Error:118.27510304370908
# ---Iteration 176
# Synthesis:(176, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 177
# Synthesis:(177, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 178
# Synthesis:(178, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 179
# Synthesis:(179, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 180
# Synthesis:(180, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 181
# Synthesis:(181, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 182
# Synthesis:(182, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 183
# Synthesis:(183, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 184
# Synthesis:(184, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 185
# Synthesis:(185, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 186
# Synthesis:(186, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 187
# Synthesis:(187, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 188
# Synthesis:(188, 0, 0)
# New RGB Measurement: (172, 54, 49)
# Characterisation:(172, 54, 49)
# Error:110.48076755707302
# ---Iteration 189
# Synthesis:(189, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 190
# Synthesis:(190, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 191
# Synthesis:(191, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 192
# Synthesis:(192, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 193
# Synthesis:(193, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 194
# Synthesis:(194, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 195
# Synthesis:(195, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 196
# Synthesis:(196, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 197
# Synthesis:(197, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 198
# Synthesis:(198, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 199
# Synthesis:(199, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 200
# Synthesis:(200, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 201
# Synthesis:(201, 0, 0)
# New RGB Measurement: (176, 51, 47)
# Characterisation:(176, 51, 47)
# Error:105.12373661547615
# ---Iteration 202
# Synthesis:(202, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 203
# Synthesis:(203, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 204
# Synthesis:(204, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 205
# Synthesis:(205, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 206
# Synthesis:(206, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 207
# Synthesis:(207, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 208
# Synthesis:(208, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 209
# Synthesis:(209, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 210
# Synthesis:(210, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 211
# Synthesis:(211, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 212
# Synthesis:(212, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 213
# Synthesis:(213, 0, 0)
# New RGB Measurement: (181, 48, 44)
# Characterisation:(181, 48, 44)
# Error:98.56977224281286
# ---Iteration 214
# Synthesis:(214, 0, 0)
# New RGB Measurement: (181, 48, 43)
# Characterisation:(181, 48, 43)
# Error:98.12746812182611
# ---Iteration 215
# Synthesis:(215, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 216
# Synthesis:(216, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 217
# Synthesis:(217, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 218
# Synthesis:(218, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 219
# Synthesis:(219, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 220
# Synthesis:(220, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 221
# Synthesis:(221, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 222
# Synthesis:(222, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 223
# Synthesis:(223, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 224
# Synthesis:(224, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 225
# Synthesis:(225, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 226
# Synthesis:(226, 0, 0)
# New RGB Measurement: (185, 45, 43)
# Characterisation:(185, 45, 43)
# Error:93.66963221877195
# ---Iteration 227
# Synthesis:(227, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 228
# Synthesis:(228, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 229
# Synthesis:(229, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 230
# Synthesis:(230, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 231
# Synthesis:(231, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 232
# Synthesis:(232, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 233
# Synthesis:(233, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 234
# Synthesis:(234, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 235
# Synthesis:(235, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 236
# Synthesis:(236, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 237
# Synthesis:(237, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 238
# Synthesis:(238, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 239
# Synthesis:(239, 0, 0)
# New RGB Measurement: (188, 43, 41)
# Characterisation:(188, 43, 41)
# Error:89.5488693395958
# ---Iteration 240
# Synthesis:(240, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 241
# Synthesis:(241, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 242
# Synthesis:(242, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 243
# Synthesis:(243, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 244
# Synthesis:(244, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 245
# Synthesis:(245, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 246
# Synthesis:(246, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 247
# Synthesis:(247, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 248
# Synthesis:(248, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 249
# Synthesis:(249, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 250
# Synthesis:(250, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 251
# Synthesis:(251, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 252
# Synthesis:(252, 0, 0)
# New RGB Measurement: (191, 41, 40)
# Characterisation:(191, 41, 40)
# Error:85.8894638474359
# ---Iteration 253
# Synthesis:(253, 0, 0)
# New RGB Measurement: (194, 40, 39)
# Characterisation:(194, 40, 39)
# Error:82.71638289964086
# ---Iteration 254
# Synthesis:(254, 0, 0)
# New RGB Measurement: (194, 40, 39)
# Characterisation:(194, 40, 39)
# Error:82.71638289964086
# -1

# %%
import matplotlib.pyplot as plt
# Plot error for each iteration
plt.scatter(range(len(error_values)), error_values, label="Error for each iteration")

# Calculate best error so far
best_error_so_far = 1000
best_errors = []
for value in error_values:
    if value < best_error_so_far:
        best_error_so_far = value
    best_errors.append(best_error_so_far)
    
# Plot best error so far
plt.plot(best_errors, label="Best Error So Far", color="orange")
plt.plot(samples['R'], color='red')
plt.plot(samples['G'], color='green')
plt.plot(samples['B'], color='blue')
plt.legend()

# %%
samples
# Out:
#        R    G   B       error   ID
# 0    107   97  97  201.796928    0
# 1    107   97  97  201.796928    1
# 2    107   97  97  201.796928    2
# 3    107   97  97  201.796928    3
# 4    107   97  97  201.796928    4
# ..   ...  ...  ..         ...  ...
# 245   28  219  32  317.039430  245
# 246   28  219  32  317.039430  246
# 247   28  219  32  317.039430  247
# 248   28  219  32  317.039430  248
# 249   28  219  32  317.039430  249
#
# [250 rows x 5 columns]
